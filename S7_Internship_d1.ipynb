# %% [markdown]
# <a href="https://colab.research.google.com/github/Aysha2004/S7_INTERNSHIP/blob/main/S7_Internship_d1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/titanic uncleaned.csv')

# %%
df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
# 5          897         0       3
# 6          898         1       3
# 7          899         0       2
# 8          900         1       3
# 9          901         0       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# 5                    Svensson, Mr. Johan Cervin    male  14.0      0      0
# ...

# %%
df.tail(10)
# Out:
#      PassengerId  Survived  Pclass  \
# 408         1300         1       3
# 409         1301         1       3
# 410         1302         1       3
# 411         1303         1       1
# 412         1304         1       3
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 408                  Riordan, Miss. Johanna Hannah""  female   NaN      0
# 409                        Peacock, Miss. Treasteall  female   3.0      1
# 410                           Naughton, Miss. Hannah  female   NaN      0
# 411  Minahan, Mrs. William Edward (Lillian E Thorpe)  female  37.0      1
# 412                   Henriksson, Miss. Jenny Lovisa  female  28.0      0
# 413                               Spector, Mr. Woolf    male   NaN      0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
#  2   Pclass       418 non-null    int64
#  3   Name         418 non-null    object
#  4   Sex          418 non-null    object
#  5   Age          332 non-null    float64
#  6   SibSp        418 non-null    int64
#  7   Parch        418 non-null    int64
#  8   Ticket       418 non-null    object
#  9   Fare         417 non-null    float64
#  10  Cabin        91 non-null     object
#  11  Embarked     418 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 39.3+ KB

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   418.000000  418.000000  418.000000  332.000000  418.000000
# mean   1100.500000    0.363636    2.265550   30.272590    0.447368
# std     120.810458    0.481622    0.841838   14.181209    0.896760
# min     892.000000    0.000000    1.000000    0.170000    0.000000
# 25%     996.250000    0.000000    1.000000   21.000000    0.000000
# 50%    1100.500000    0.000000    3.000000   27.000000    0.000000
# 75%    1204.750000    1.000000    3.000000   39.000000    1.000000
# max    1309.000000    1.000000    3.000000   76.000000    8.000000
#
#             Parch        Fare
# count  418.000000  417.000000
# mean     0.392344   35.627188
# std      0.981429   55.907576
# min      0.000000    0.000000
# 25%      0.000000    7.895800
# 50%      0.000000   14.454200
# 75%      0.000000   31.500000
# max      9.000000  512.329200

# %%
df.head(10)[['Pclass','Survived']]
# Out:
#    Pclass  Survived
# 0       3         0
# 1       3         1
# 2       2         0
# 3       3         0
# 4       3         1
# 5       3         0
# 6       3         1
# 7       2         0
# 8       3         1
# 9       3         0

# %%
df.shape
# Out:
# (418, 12)

# %%
df.isnull()
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 413        False     False   False  False  False   True  False  False   False
# 414        False     False   False  False  False  False  False  False   False
# 415        False     False   False  False  False  False  False  False   False
# 416        False     False   False  False  False   True  False  False   False
# 417        False     False   False  False  False   True  False  False   False
#
#       Fare  Cabin  Embarked
# ...

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
df['Age_mean_imputed'] = df['Age'].fillna(df['Age'].mean())
df['Age_median_imputed'] = df['Age'].fillna(df['Age'].median())

# %%
df['Cabin_mode_imputed'] = df['Cabin'].fillna(df['Cabin'].mode()[0])

# %%
df.head(10)[['Age','Age_mean_imputed','Age_median_imputed','Cabin','Cabin_mode_imputed']]
# Out:
#     Age  Age_mean_imputed  Age_median_imputed Cabin Cabin_mode_imputed
# 0  34.5              34.5                34.5   NaN    B57 B59 B63 B66
# 1  47.0              47.0                47.0   NaN    B57 B59 B63 B66
# 2  62.0              62.0                62.0   NaN    B57 B59 B63 B66
# 3  27.0              27.0                27.0   NaN    B57 B59 B63 B66
# 4  22.0              22.0                22.0   NaN    B57 B59 B63 B66
# 5  14.0              14.0                14.0   NaN    B57 B59 B63 B66
# 6  30.0              30.0                30.0   NaN    B57 B59 B63 B66
# 7  26.0              26.0                26.0   NaN    B57 B59 B63 B66
# 8  18.0              18.0                18.0   NaN    B57 B59 B63 B66
# 9  21.0              21.0                21.0   NaN    B57 B59 B63 B66

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.set(style = 'whitegrid')

# %%
plt.figure(figsize = (10,6))

# %%
sns.boxplot(data = df, x = 'Pclass', y = 'Age', palette = 'pastel', hue = 'Pclass')
plt.title('Boxplot of age by passenger class', fontsize = 20)
plt.xlabel('Passenger class', fontsize = 15)
plt.ylabel('Age', fontsize = 15)
plt.show()

# %%
sns.barplot(data = df, x = 'Pclass', y = 'Survived', hue = 'Pclass', palette = 'pastel')
plt.title('Boxplot of survived by passenger class', fontsize = 20)
plt.xlabel('Passenger class', fontsize = 15)
plt.ylabel('Survived', fontsize = 15)
plt.show()

# %%
sns.boxplot(data = df, x = 'Embarked', y = 'Fare', palette = 'pastel', hue = 'Embarked')
plt.title('Boxplot of fare by embarked', fontsize = 20)
plt.xlabel('Embarked', fontsize = 15)
plt.ylabel('Fare', fontsize = 15)
plt.show()

# %%
sns.barplot(data = df, x = 'Embarked', y = 'Fare', hue = 'Embarked', palette = 'pastel')
plt.xlabel('Embarked', fontsize = 15)
plt.ylabel('Fare', fontsize = 15)
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder

# %%
encoded_data = df.copy()

# %%
label_encoder = LabelEncoder()

# %%
encoded_data['Sex_label_encoded'] = label_encoder.fit_transform(encoded_data['Sex'])

# %%
one_hot_encoded = pd.get_dummies(encoded_data['Embarked'], prefix = 'Embarked')
encoded_data = pd.concat([encoded_data, one_hot_encoded], axis = 1)

# %%
pclass_mapping = {1: 'First', 2: 'Second', 3: 'Third'}
encoded_data['Pclass_Category'] = encoded_data['Pclass'].map(pclass_mapping)

# %%
print(encoded_data[['Sex', 'Sex_label_encoded', 'Embarked_Q', 'Embarked_S']])
# Out:
#         Sex  Sex_label_encoded  Embarked_Q  Embarked_S
# 0      male                  1        True       False
# 1    female                  0       False        True
# 2      male                  1        True       False
# 3      male                  1       False        True
# 4    female                  0       False        True
# ..      ...                ...         ...         ...
# 413    male                  1       False        True
# 414  female                  0       False       False
# 415    male                  1       False        True
# 416    male                  1       False        True
# 417    male                  1       False       False
#
# [418 rows x 4 columns]

# %%
numerical_columns = ['Age', 'Fare','Pclass']

# %%
from sklearn.preprocessing import MinMaxScaler, StandardScaler, RobustScaler

# %%
df.dropna(subset = numerical_columns, inplace = True)

# %%
minmax_scaler = MinMaxScaler()
standard_scaler = StandardScaler()
robust_scaler = RobustScaler()

# %%
df['Age_MinMax'] = minmax_scaler.fit_transform(df[['Age']])
df['Fare_MinMax'] = minmax_scaler.fit_transform(df[['Fare']])

df['Age_Standard'] = standard_scaler.fit_transform(df[['Age']])
df['Fare_Standard'] = standard_scaler.fit_transform(df[['Fare']])

df['Age_Robust'] = robust_scaler.fit_transform(df[['Age']])
df['Fare_Robust'] = robust_scaler.fit_transform(df[['Fare']])

# %%
 df[['Age','Age_MinMax','Age_Standard','Age_Robust']]
# Out:
#       Age  Age_MinMax  Age_Standard  Age_Robust
# 0    34.5    0.452723      0.306657    0.416667
# 1    47.0    0.617566      1.194236    1.111111
# 2    62.0    0.815377      2.259331    1.944444
# 3    27.0    0.353818     -0.225890    0.000000
# 4    22.0    0.287881     -0.580922   -0.277778
# ..    ...         ...           ...         ...
# 409   3.0    0.037320     -1.930042   -1.333333
# 411  37.0    0.485692      0.484173    0.555556
# 412  28.0    0.367005     -0.154884    0.055556
# 414  39.0    0.512066      0.626186    0.666667
# 415  38.5    0.505473      0.590683    0.638889
#
# [331 rows x 4 columns]
